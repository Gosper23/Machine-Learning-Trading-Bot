# %%
import pandas as pd
import numpy as np
from pathlib import Path
import hvplot.pandas
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.preprocessing import StandardScaler
from pandas.tseries.offsets import DateOffset
from sklearn.metrics import classification_report
from sklearn import svm
from sklearn.metrics import classification_report
import warnings
warnings.filterwarnings('ignore')
from pathlib import Path

# %%
tsla_data = pd.read_csv(
    Path("../resources/technical_indicator_data.csv"),
    index_col="Date",
    parse_dates=True, 
    infer_datetime_format=True
)

tsla_data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-06-05   67.699997   69.688004   66.842003   69.463997   69.463997
# 2017-06-06   68.940002   71.898003   67.994003   70.570000   70.570000
# 2017-06-07   71.267998   72.099998   71.028000   71.930000   71.930000
# 2017-06-08   72.750000   74.379997   72.043999   74.000000   74.000000
# 2017-06-09   74.884003   75.374001   70.959999   71.463997   71.463997
# ...                ...         ...         ...         ...         ...
# 2022-05-27  723.250000  759.799988  720.530029  759.630005  759.630005
# 2022-05-31  773.840027  778.799988  734.229980  758.260010  758.260010
# 2022-06-01  755.159973  771.979980  730.919983  740.369995  740.369995
# 2022-06-02  732.469971  792.630005  726.200012  775.000000  775.000000
# 2022-06-03  729.679993  743.390015  700.250000  703.549988  703.549988
#
#               Volume       SMA50      SMA100  SMA_Signal  SMA_Entry/Exit  \
# Date
# 2017-06-05  33922000         NaN         NaN         0.0             NaN
# 2017-06-06  55434000         NaN         NaN         0.0             0.0
# 2017-06-07  46990000         NaN         NaN         0.0             0.0
# 2017-06-08  45307500         NaN         NaN         0.0             0.0
# 2017-06-09  86307000         NaN         NaN         0.0             0.0
# ...              ...         ...         ...         ...             ...
# 2022-05-27  29765000  909.515197  908.520997         1.0             1.0
# 2022-05-31  33971500  906.572596  905.222397         1.0             0.0
# 2022-06-01  25749300  902.956797  901.979097         1.0             0.0
# 2022-06-02  31157700  898.577197  899.459498         0.0            -1.0
# 2022-06-03  37348100  892.665997  895.913798         0.0             0.0
#
#               BB_UPPER   BB_MIDDLE    BB_LOWER  BB_Signal  Signal  \
# Date
# 2017-06-05         NaN         NaN         NaN        0.0     NaN
# 2017-06-06         NaN         NaN         NaN        0.0     NaN
# 2017-06-07         NaN         NaN         NaN        0.0     NaN
# 2017-06-08         NaN         NaN         NaN        0.0     NaN
# 2017-06-09         NaN         NaN         NaN        0.0     NaN
# ...                ...         ...         ...        ...     ...
# 2022-05-27  949.794758  766.040500  582.286241        0.0     NaN
# 2022-05-31  930.889209  758.806500  586.723792        0.0     NaN
# 2022-06-01  907.266637  750.362500  593.458363        0.0     NaN
# 2022-06-02  867.188999  741.481500  615.774002        0.0     NaN
# 2022-06-03  843.199416  732.994998  622.790580        0.0     NaN
#
#             BB_Entry/Exit       EMA50      EMA100  EMA_Signal  EMA_Entry/Exit
# Date
# 2017-06-05            NaN   69.463997   69.463997         0.0             NaN
# 2017-06-06            0.0   70.028058   70.022528         0.0             0.0
# 2017-06-07            0.0   70.687564   70.671111         0.0             0.0
# 2017-06-08            0.0   71.566008   71.528464         0.0             0.0
# 2017-06-09            0.0   71.543942   71.515050         0.0             0.0
# ...                   ...         ...         ...         ...             ...
# 2022-05-27            0.0  844.711211  885.825845         0.0             0.0
# 2022-05-31            0.0  841.320968  883.299789         0.0             0.0
# 2022-06-01            0.0  837.362106  880.469496         0.0             0.0
# 2022-06-02            0.0  834.916533  878.380991         0.0             0.0
# 2022-06-03            0.0  829.764904  874.918991         0.0             0.0
#
# [1260 rows x 20 columns]

# %%
# Use the pct_change function to generate  returns from close prices
tsla_data["Actual Returns"] = tsla_data["Close"].pct_change()

# Drop all NaN values from the DataFrame
tsla_data = tsla_data.dropna()

# Review the DataFrame
display(tsla_data.head())
display(tsla_data.tail())
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 
# 2022-04-26  953.457863         1.0             0.0       -0.121841
# 2022-04-27  952.033153         1.0             0.0        0.005808
# 2022-05-09  941.231320         1.0             0.0       -0.090730
# 2022-05-11  934.387226         0.0             0.0       -0.082546
#
#             Strategy Returns
# Date
# 2022-03-28         -0.080345
# 2022-04-26          0.121841
# 2022-04-27          0.005808
# 2022-05-09         -0.090730
# 2022-05-11         -0.082546
#
# [5 rows x 22 columns]

# %%
# Plot Strategy Returns to examine performance
(1 + tsla_data['Strategy Returns']).cumprod().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.savefig("Strategy Return plot")

# %% [markdown]
# # Split the data into training and testing datasets

# %%
# Assign a copy of the sma_fast and sma_slow columns to a features DataFrame called X
X = tsla_data[['SMA100', 'SMA50']].shift().dropna()

# Review the DataFrame
X.head()
# Out:
#               SMA100     SMA50
# Date
# 2017-10-26  70.21578  70.55548
# 2017-10-27  70.16242  70.40852
# 2017-11-02  70.08486  70.28432
# 2017-12-11  69.70420  69.85436
# 2017-12-12  67.71134  65.12412

# %%
# Create the target set selecting the Signal column and assiging it to y
y = tsla_data['SMA_Signal']

# Review the value counts
y.value_counts()
# Out:
# 1.0    94
# 0.0    55
# Name: SMA_Signal, dtype: int64

# %%
# Select the start of the training period
training_begin = X.index.min()

# Display the training begin date
print(training_begin)
# Out:
# 2017-10-26 00:00:00

# %%
# Select the ending period for the training data with an offset of 3 months
training_end = X.index.min() + DateOffset(months=12)

# Display the training end date
print(training_end)
# Out:
# 2018-10-26 00:00:00

# %%
# Generate the X_train and y_train DataFrames
X_train = X.loc[training_begin:training_end]
y_train = y.loc[training_begin:training_end]

# Review the X_train DataFrame
X_train.tail()
# Out:
#               SMA100     SMA50
# Date
# 2018-09-28  62.62458  63.90464
# 2018-10-05  62.64444  62.18332
# 2018-10-08  62.56688  61.86612
# 2018-10-25  62.49504  61.67964
# 2018-10-26  62.14400  58.04592

# %%
# Generate the X_test and y_test DataFrames
X_test = X.loc[training_end+DateOffset(hours=1):]
y_test = y.loc[training_end+DateOffset(hours=1):]

# Review the X_test DataFrame
X_train.head()
# Out:
#               SMA100     SMA50
# Date
# 2017-10-26  70.21578  70.55548
# 2017-10-27  70.16242  70.40852
# 2017-11-02  70.08486  70.28432
# 2017-12-11  69.70420  69.85436
# 2017-12-12  67.71134  65.12412

# %%
# Scale the features DataFrames

# Create a StandardScaler instance
scaler = StandardScaler()

# Apply the scaler model to fit the X-train data
X_scaler = scaler.fit(X_train)

# Transform the X_train and X_test DataFrames using the X_scaler
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Use SVC classifier model from SKLearn suport vector machine SVM learning method to fit the training data and make predictions

# %%
# From SVM, instantiate SVC classifier model instance
svm_model = svm.SVC()
 
# Fit the model to the data using the training data
svm_model = svm_model.fit(X_train_scaled, y_train)
 
# Use the testing data to make the model predictions
svm_pred = svm_model.predict(X_train_scaled)

# Review the model's predicted values
svm_pred[:10]
# Out:
# array([1., 1., 1., 1., 0., 0., 0., 0., 0., 1.])

# %% [markdown]
# # Review the classification report associated with the SVC model predictions

# %%
# Use a classification report to evaluate the model using the predictions and testing data
svm_testing_report = classification_report(y_train, svm_pred)

# Print the classification report
print(svm_testing_report)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.82      0.85        17
#          1.0       0.77      0.83      0.80        12
#
#     accuracy                           0.83        29
#    macro avg       0.82      0.83      0.82        29
# weighted avg       0.83      0.83      0.83        29

# %% [markdown]
# # create a predictions dataframe that contains columns for predicted values, actual returns and strategy returns

# %%
# Create a new empty predictions DataFrame.
testing_signal_predictions = svm_model.predict(X_test_scaled)
# Create a predictions DataFrame
predictions_df = pd.DataFrame(index=X_test.index)

# Add the SVM model predictions to the DataFrame
predictions_df['Predicted'] = testing_signal_predictions

# Add the actual returns to the DataFrame
predictions_df['Actual Returns'] = signals_df['Actual Returns']

# Add the strategy returns to the DataFrame
predictions_df['Strategy Returns'] = predictions_df['Actual Returns'] * predictions_df['Predicted']

# Review the DataFrame
display(predictions_df.head())
display(predictions_df.tail())
# Out:
#             Predicted  Actual Returns  Strategy Returns
# Date
# 2018-10-29        0.0        0.011937          0.000000
# 2018-12-13        0.0        0.027796          0.000000
# 2018-12-20        1.0       -0.052828         -0.052828
# 2018-12-24        1.0       -0.076242         -0.076242
# 2019-03-04        1.0       -0.031989         -0.031989
#             Predicted  Actual Returns  Strategy Returns
# Date
# 2022-03-28        1.0        0.080345          0.080345
# 2022-04-26        1.0       -0.121841         -0.121841
# 2022-04-27        1.0        0.005808          0.005808
# 2022-05-09        1.0       -0.090730         -0.090730
# 2022-05-11        1.0       -0.082546         -0.082546

# %% [markdown]
# # create a cumulative return plot that shows the actual returns vs. the strategy returns.

# %%
# Plot the actual returns versus the strategy returns
(1 + predictions_df[["Actual Returns", "Strategy Returns"]]).cumprod().plot()
(1 + predictions_df[["Actual Returns", "Strategy Returns"]])
# Out:
#             Actual Returns  Strategy Returns
# Date
# 2018-10-29        1.011937          1.000000
# 2018-12-13        1.027796          1.000000
# 2018-12-20        0.947172          0.947172
# 2018-12-24        0.923758          0.923758
# 2019-03-04        0.968011          0.968011
# ...                    ...               ...
# 2022-03-28        1.080345          1.080345
# 2022-04-26        0.878159          0.878159
# 2022-04-27        1.005808          1.005808
# 2022-05-09        0.909270          0.909270
# 2022-05-11        0.917454          0.917454
#
# [119 rows x 2 columns]

# %%
plt.savefig("CumulativeReturnplot12mthoffset.png")

# %% [markdown]
# # Evaluate Machine Learning Classifier

# %%
# Import a new classifier from SKLearn
from sklearn.ensemble import RandomForestClassifier

# Initiate the model instance
RF_model = RandomForestClassifier(n_estimators=10, max_depth=None,
    min_samples_split=2, random_state=0)

RF_model
# Out:
# RandomForestClassifier(n_estimators=10, random_state=0)

# %% [markdown]
# # using the original training data as baseline model, fit another model with the new classifier

# %%
# Fit the model using the training data
RF_model = RF_model.fit(X_train_scaled, y_train)

# Use the testing dataset to generate the predictions for the new model
RF_model_predictions = RF_model.predict(X_train_scaled)

# Review the model's predicted values
RF_model_predictions[:10]
# Out:
# array([1., 1., 1., 0., 0., 0., 0., 0., 1., 1.])

# %% [markdown]
# # back test the new model to evaluate performance

# %%
# Use a classification report to evaluate the model using the predictions and testing data
RF_training_report = classification_report(y_test, testing_signal_predictions)

# Print the classification report
print(RF_training_report)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.16      0.27        38
#          1.0       0.71      0.99      0.83        81
#
#     accuracy                           0.72       119
#    macro avg       0.79      0.57      0.55       119
# weighted avg       0.76      0.72      0.65       119

# %%
# Create a new empty predictions DataFrame.
testing_signal_predictions = RF_model.predict(X_test_scaled)
# Create a predictions DataFrame
predictions_df = pd.DataFrame(index=X_test.index)

# Add the SVM model predictions to the DataFrame
predictions_df['Predicted'] = testing_signal_predictions

# Add the actual returns to the DataFrame
predictions_df['Actual Returns'] = tsla_data['Actual Returns']

# Add the strategy returns to the DataFrame
predictions_df['Strategy Returns'] = predictions_df['Actual Returns'] * predictions_df['Predicted']

# Review the DataFrame
display(predictions_df.head())
display(predictions_df.tail())
# Out:
#             Predicted  Actual Returns  Strategy Returns
# Date
# 2018-10-29        0.0        0.011937          0.000000
# 2018-12-13        0.0        0.027796          0.000000
# 2018-12-20        1.0       -0.052828         -0.052828
# 2018-12-24        0.0       -0.076242         -0.000000
# 2019-03-04        1.0       -0.031989         -0.031989
#             Predicted  Actual Returns  Strategy Returns
# Date
# 2022-03-28        1.0        0.080345          0.080345
# 2022-04-26        1.0       -0.121841         -0.121841
# 2022-04-27        1.0        0.005808          0.005808
# 2022-05-09        1.0       -0.090730         -0.090730
# 2022-05-11        1.0       -0.082546         -0.082546

# %%
# Plot the actual returns versus the strategy returns
(1 + predictions_df[["Actual Returns", "Strategy Returns"]]).cumprod().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.savefig("RF Prediction - 12mth Offset")

# %%
# Now we will look at AdaBoostClassifier as a comparison supervised learning moduel 
# Import a new classifier from SKLearn

from sklearn.model_selection import cross_val_score
from sklearn.datasets import load_iris
from sklearn.ensemble import AdaBoostClassifier

# %%
ada_model = AdaBoostClassifier(n_estimators=100)

ada_model
# Out:
# AdaBoostClassifier(n_estimators=100)

# %%
ada_model = ada_model.fit(X_train_scaled, y_train)
ada_model_predictions = ada_model.predict(X_train_scaled)
# Review the model's predicted values
ada_model_predictions[:10]
# Out:
# array([1., 1., 1., 0., 0., 0., 0., 0., 1., 1.])

# %%
# Use a classification report to evaluate the model using the predictions and testing data
ada_training_report = classification_report(y_test, testing_signal_predictions)

# Print the classification report
print(ada_training_report)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.39      0.48        38
#          1.0       0.76      0.89      0.82        81
#
#     accuracy                           0.73       119
#    macro avg       0.69      0.64      0.65       119
# weighted avg       0.72      0.73      0.71       119

# %%
# Create a new empty predictions DataFrame.
testing_signal_predictions = ada_model.predict(X_test_scaled)
# Create a predictions DataFrame
predictions_df = pd.DataFrame(index=X_test.index)

# Add the ADA boost model predictions to the DataFrame
predictions_df['Predicted'] = testing_signal_predictions

# Add the actual returns to the DataFrame
predictions_df['Actual Returns'] = signals_df['Actual Returns']

# Add the strategy returns to the DataFrame
predictions_df['Strategy Returns'] = predictions_df['Actual Returns'] * predictions_df['Predicted']

# Review the DataFrame
display(predictions_df.head())
display(predictions_df.tail())
# Out:
#             Predicted  Actual Returns  Strategy Returns
# Date
# 2018-10-29        0.0        0.011937          0.000000
# 2018-12-13        0.0        0.027796          0.000000
# 2018-12-20        0.0       -0.052828         -0.000000
# 2018-12-24        0.0       -0.076242         -0.000000
# 2019-03-04        1.0       -0.031989         -0.031989
#             Predicted  Actual Returns  Strategy Returns
# Date
# 2022-03-28        1.0        0.080345          0.080345
# 2022-04-26        1.0       -0.121841         -0.121841
# 2022-04-27        1.0        0.005808          0.005808
# 2022-05-09        1.0       -0.090730         -0.090730
# 2022-05-11        1.0       -0.082546         -0.082546

# %%
# Plot the actual returns versus the strategy returns
(1 + predictions_df[["Actual Returns", "Strategy Returns"]]).cumprod().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.savefig("ADA Boost Prediction 12mth Offset")
